# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams.update({'font.size': 22})

# %% [markdown]
# # Data Visualization using Seaborn & Python 3  ##
# **by: Lauren Washington**
# **February 2018**

# %%
df = pd.read_csv("movie_ratings.csv")

# %%
#view column names
df.columns
# Out:
# Index(['Day of Week', 'Director', 'Genre', 'Movie Title', 'Release Date',
#        'Studio', 'Adjusted Gross ($mill)', 'Budget ($mill)', 'Gross ($mill)',
#        'IMDb Rating', 'MovieLens Rating', 'Overseas ($mill)', 'Overseas%',
#        'Profit ($mill)', 'Profit%', 'Runtime (min)', 'US ($mill)',
#        'Gross % US'],
#       dtype='object')

# %%
#rename columns
df.rename(columns={'Day of Week':'Day_of_Week'}, inplace = True) 
df.rename(columns={'Adjusted Gross ($mill)':'Adjusted_Gross'}, inplace = True) 
df.rename(columns={'Budget ($mill)':'Budget'}, inplace = True) 
df.rename(columns={'Gross ($mill)':'Gross'}, inplace = True) 
df.rename(columns={'IMDb Rating':'IMDb_Rating'}, inplace = True)
df.rename(columns={'MovieLens Rating':'MovieLens_Rating'}, inplace = True) 
df.rename(columns={'Overseas ($mill)':'Overseas'}, inplace = True)
df.rename(columns={'Profit ($mill)':'Profit'}, inplace = True) 
df.rename(columns={'US ($mill)':'US'}, inplace = True) 
df.rename(columns={'Movie Title':'Movie'}, inplace = True) 
df.rename(columns={'Release Date':'Release_Date'}, inplace = True) 
df.rename(columns={'Runtime (min)':'Runtime'}, inplace=True)

# %%
df['Day_of_Week'] = df['Day_of_Week'].astype('category')
df['Day_of_Week'] = df['Day_of_Week'].cat.set_categories(["Monday","Tuesday","Wednesday", 
                                                   "Thursday", "Friday", "Saturday", "Sunday"], ordered=True)

# %%
df["weekend"] = df["Day_of_Week"].isin(["Friday", "Saturday", "Sunday"])

# %%
#view first 5 lines
df.head()
# Out:
#   Day_of_Week                 Director   Genre              Movie  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release_Date               Studio  Adjusted_Gross  Budget  Gross  \
# 0   22/05/2015  Buena Vista Studios           202.1   170.0  202.1
# 1   14/03/2014  Buena Vista Studios           204.2    66.0  203.3
# 2   15/08/2014            Lionsgate           207.1   100.0  206.2
# 3   16/03/2012                 Sony           208.8    42.0  201.6
# 4   28/06/2013                 Sony           209.7   150.0  205.4
#
#    IMDb_Rating  MovieLens_Rating  Overseas  Overseas%  Profit  Profit%  \
# 0          6.7              3.26     111.9       55.4    32.1     18.9
# 1          6.6              2.97     159.7       78.6   137.3    208.0
# 2          6.1              2.93     166.9       80.9   106.2    106.2
# 3          7.2              3.62      63.1       31.3   159.6    380.0
# 4          8.0              3.65     132.3       64.4    55.4     36.9
#
#    Runtime     US  Gross % US
# 0      130   90.2        44.6
# 1      132   43.6        21.4
# 2      126   39.3        19.1
# 3      109  138.4        68.7
# 4      131   73.1        35.6

# %%
#view summary stats of numeric variables
df.describe()
# Out:
#        Adjusted_Gross      Budget        Gross  IMDb_Rating  MovieLens_Rating  \
# count      608.000000  608.000000   608.000000   608.000000        608.000000
# mean       545.153125   92.467928   413.466118     6.923849          3.340378
# std        438.996563   59.421407   258.612104     0.925890          0.454071
# min        202.100000    0.600000   200.300000     3.600000          1.490000
# 25%        316.950000   45.000000   246.600000     6.375000          3.037500
# 50%        425.950000   80.000000   327.750000     6.900000          3.365000
# 75%        645.625000  130.000000   475.500000     7.600000          3.672500
# max       6846.700000  300.000000  2788.000000     9.200000          4.500000
#
#           Overseas   Overseas%       Profit       Profit%     Runtime  \
# count   608.000000  608.000000   608.000000    608.000000  608.000000
# mean    246.332237   57.698849   320.945559    719.278783  117.781250
# std     184.581069   12.334237   233.887737   1942.807248   23.179122
# min      46.900000   17.200000    19.900000      7.700000   30.000000
# 25%     135.525000   49.900000   180.700000    201.850000  100.000000
# 50%     189.650000   58.200000   247.700000    338.550000  116.000000
# 75%     283.650000   66.300000   389.750000    650.100000  130.250000
# max    2027.500000  100.000000  2551.000000  41333.300000  238.000000
#
#                US  Gross % US
# count  608.000000  608.000000
# mean   167.135197   42.301151
# std     92.465903   12.334237
# min      0.000000    0.000000
# 25%    106.950000   33.700000
# 50%    141.700000   41.800000
# 75%    202.100000   50.100000
# max    760.500000   82.800000

# %% [markdown]
# **Categorical vs Continuous Variables**
#
# For **categorical** variables utilize **bar charts and boxplots**.
#
# For **continuous** variables utilize **histograms, scatterplots, line graphs, and boxplots.**

# %% [markdown]
# **Bar Chart:**  a graph in which a summary statistic (ususally the mean) is plotted on the y-axis against a categorical variable on the x-axis (this categorica variable could represent, for example, groups of people, different times, or different experimental conditions), A bar shows the value of the mean for each category. Different-couloured bars may be used to represent levels of a second categorical variable.
#
# **Boxplot or Box-whisker plot:** a graphical representation of some important characteristics of a set of observations. At the center of the plot is the median, which is surrounded by a box, the top and bottom of which are the limits within which the middle 50% of observations fall (the interquartile range). Sticking out of the top and bottom of the box are two whiskers, which extend to the most and least extreme scores respectively.
#
# **Histogram or Frequency Distribution:** a graph plotting values of observations on the horizontal axis , and the frequency with which each value occurs in the data set on the vertical axis.
#
# **Kernel Density Estimate:** Similar to a histogra except that, rather than having a summary bar representing the frequency of scores, it shows each individual score as a dot. They can be useful for looking at the shape of a distribuution of scores. Overall, it's the probability that a data point will be present at any point in the n-dimensional space defined by the number of features. You can visualize these probabilities as a surface having hills that "peak" where many data points are present, and flat areas or valleys where few data points are present. The "peaks" represent what will become the cluster means. This surface of probabilities is called a kernel density surface.
#
# **Line Chart:** a graph in which a summary statistic (usually the mean) is plotted on the y-axis against a categorical variable on the x-axis (this categorical variable could represent, for example, groups of people, different times, or different experimental conditions). The value of the mean for each category is shown by a symbol, and means across categories are connected by a line. Different coloured lines may be used to represent levels of a second categorical variable.
#
# **Scatterplot:** a graph that plots values of one variable against the corresponding value of another variable.

# %% [markdown]
# ## Plotting Univariate Distributions
#
# **Univariate:** means 'one variable' and is usually used to refer to situations in which only one outcome variable has been measured (i.e., ANOVA, t-tests, Mann-Whitney tests, etc)

# %%
#distplot plots kernel density estimate by default. for reg histogram set to False
sns.distplot(df.Runtime, kde=False)
plt.xlabel('Movie Runtime')
plt.ylabel('Frequency')
plt.title('Movie Runtime Frequency Distribution');

# %%
#add in bins parameter
sns.distplot(df.Runtime, bins = 20, kde=False)
plt.xlabel('Movie Runtime')
plt.ylabel('Frequency')
plt.title('Movie Runtime Frequency Distribution');

# %%
#don't suppress kernel density estimate
sns.distplot(df.Runtime)
plt.xlabel('Movie Runtime')
plt.ylabel('Frequency')
plt.title('Movie Runtime Frequency Distribution');

# %%
#add a rug plot
sns.distplot(df.Runtime, kde=False, rug = True)
plt.xlabel('Movie Runtime')
plt.ylabel('Frequency')
plt.title('Movie Runtime Frequency Distribution');

# %%
#density, rug, no hist
sns.distplot(df.Runtime, hist=False, rug=True)
plt.xlabel('Movie Runtime')
plt.ylabel('Frequency')
plt.title('Movie Runtime Frequency Distribution');

# %%
#bare kdeplot using kdeplot instead of distplot
sns.kdeplot(df.Runtime)
plt.xlabel('Movie Runtime')
plt.ylabel('Frequency')
plt.title('Movie Runtime Frequency Distribution');

# %% [markdown]
# ## Check the underlying distribution.

# %%
#check the underlying distribution
sns.distplot(df.Runtime, fit = stats.gamma)
plt.xlabel('Movie Runtime')
plt.ylabel('Density')
plt.title('Movie Runtime Frequency/KDE');

# %% [markdown]
# ## Plotting Bivariate Correlations

# %% [markdown]
# **Bivariate Correlation:** a correlation between two variables

# %%
df.corr()
# Out:
#                   Adjusted_Gross    Budget     Gross  IMDb_Rating  \
# Adjusted_Gross          1.000000  0.148537  0.655192     0.272071
# Budget                  0.148537  1.000000  0.511863    -0.026303
# Gross                   0.655192  0.511863  1.000000     0.267442
# IMDb_Rating             0.272071 -0.026303  0.267442     1.000000
# MovieLens_Rating        0.225777 -0.031066  0.212869     0.879836
# Overseas                0.594668  0.536799  0.967853     0.222273
# Overseas%               0.042319  0.301011  0.243778    -0.034393
# Profit                  0.686806  0.311910  0.975851     0.302620
# Profit%                 0.229841 -0.298632 -0.001589     0.077253
# Runtime                 0.341415  0.218664  0.280370     0.326788
# US                      0.645391  0.360020  0.864803     0.304335
# Gross % US             -0.042319 -0.301011 -0.243778     0.034393
#
#                   MovieLens_Rating  Overseas  Overseas%    Profit   Profit%  \
# Adjusted_Gross            0.225777  0.594668   0.042319  0.686806  0.229841
# Budget                   -0.031066  0.536799   0.301011  0.311910 -0.298632
# Gross                     0.212869  0.967853   0.243778  0.975851 -0.001589
# IMDb_Rating               0.879836  0.222273  -0.034393  0.302620  0.077253
# MovieLens_Rating          1.000000  0.167901  -0.057060  0.243528  0.049759
# Overseas                  0.167901  1.000000   0.445308  0.934006 -0.027440
# Overseas%                -0.057060  0.445308   1.000000  0.193524 -0.084881
# Profit                    0.243528  0.934006   0.193524  1.000000  0.074189
# Profit%                   0.049759 -0.027440  -0.084881  0.074189  1.000000
# Runtime                   0.302791  0.277475   0.086538  0.254618 -0.042088
# US                        0.260240  0.710714  -0.207146  0.864833  0.050342
# Gross % US                0.057060 -0.445308  -1.000000 -0.193524  0.084881
#
#                    Runtime        US  Gross % US
# Adjusted_Gross    0.341415  0.645391   -0.042319
# Budget            0.218664  0.360020   -0.301011
# Gross             0.280370  0.864803   -0.243778
# IMDb_Rating       0.326788  0.304335    0.034393
# MovieLens_Rating  0.302791  0.260240    0.057060
# Overseas          0.277475  0.710714   -0.445308
# Overseas%         0.086538 -0.207146   -1.000000
# Profit            0.254618  0.864833   -0.193524
# Profit%          -0.042088  0.050342    0.084881
# Runtime           1.000000  0.230268   -0.086538
# US                0.230268  1.000000    0.207146
# Gross % US       -0.086538  0.207146    1.000000

# %%
sns.jointplot(x="US", y="Gross", data=df);

# %%
sns.jointplot(x="US", y="Overseas%", data= df);

# %% [markdown]
# ## Visualize pairwise relationships

# %%
sns.pairplot(df);

# %% [markdown]
# ## Plotting Categorical Data

# %%
sns.countplot(x="Genre", data=df, palette="Blues")
plt.xticks(rotation = 90);

# %%
sns.countplot(y="Genre", hue="weekend", data=df, palette="Blues_d");

# %%
sns.boxplot(x="Genre", y="US", data=df)
plt.xticks(rotation=90);

# %%
sns.boxplot(x="Genre", y="US", hue="weekend", data=df)
plt.xticks(rotation=90);

# %%
sns.barplot(x="Genre", y="Budget", hue="weekend", data=df)
plt.xticks(rotation = 90);

# %%
sns.stripplot(x="Genre", y="Budget", data=df)
plt.xticks(rotation=90);

# %%
sns.stripplot(x="Genre", y="Budget", data=df, jitter = True)
plt.xticks(rotation=90);

# %%
sns.swarmplot(x="Genre", y="Budget", data=df)
plt.xticks(rotation=90);

# %%
sns.stripplot(x="Day_of_Week", y="Budget", hue = "Genre", data=df, jitter = True)
plt.xticks(rotation=90);

# %%
sns.stripplot(x="Budget", y="Day_of_Week", hue = "Genre", data=df, jitter = True);

# %%
sns.violinplot(x="Genre", y="US", hue="weekend", data=df, split = True)
plt.xticks(rotation=90);

# %%
sns.violinplot(x="Genre", y="US", hue="weekend", data=df, split = True, 
               inner="stick", palette="Set3")
plt.xticks(rotation = 90);

# %%
df['Budget'].describe()
# Out:
# count    608.000000
# mean      92.467928
# std       59.421407
# min        0.600000
# 25%       45.000000
# 50%       80.000000
# 75%      130.000000
# max      300.000000
# Name: Budget, dtype: float64

# %%
sns.violinplot(x="Genre", y="Budget", data=df, inner=None)
sns.swarmplot(x="Genre", y="Budget", data=df, color="w", alpha=.5)
plt.xticks(rotation = 90);

# %%
sns.pointplot(x="Genre", y="Budget", hue="weekend", data=df)
plt.xticks(rotation = 90);

# %% [markdown]
# [seasborn facet grid](https://seaborn.pydata.org/generated/seaborn.FacetGrid.html)

# %% [markdown]
# ** Additional Resources: **
# [Seaborn Graphs Gallery](https://seaborn.pydata.org/examples/index.html)
